# %% [markdown]
# # Project 1: Thu thập dữ liệu từ trang SoundCloud
#
# <p>Trang Soundcloud là một trang web cho phép người dùng upload và chia sẻ các bài
# hát. Ở đây, chúng ta sẽ thu thập thông tin về các nghệ sĩ, ban nhạc, podcast và người sáng
# tác âm nhạc trên trang SoundCloud qua 2 cách <strong>Crawl data (Parse HTML)</strong> và sử dụng <strong>API</strong>.</p>
#
#
#
# <strong>Bảng phân công công việc:</strong>
#
# | MSSV | Họ và tên | Công việc |
# | --- | --- | --- |
# | 18120429 | Thu thập các tracks bằng API |
# | 19120057 | Thu thập các users bằng API |
# | 19120145 | Thu thập các Playlists bằng API|
# | 19120124 | Cài đặt các hàm lấy dữ liệu bằng cách Parse HTML |
# | 19120142 | Lên ý tưởng, kiểm thử và thực hiện thu thập dữ liệu bằng Parse HTML |

# %% [markdown]
# #### Set up:
# * Import các thư viện cần thiết:

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
from requests_html import HTMLSession
import time
import json
import re
import pandas as pd # Dùng để đọc và hiển thị file csv/tsv
from datetime import datetime, timedelta # Dùng để xử lý dữ liệu thời gian

# %% [markdown]
# * Setup/install cache để giúp giảm số lần phải lấy dữ liệu:

# %%
def CheckCache(response):
    a='"incomplete_results":true'
    if a in response.text:
        return False
    else:
        return True

requests_cache.install_cache('demo-cache',expire_after=None,filter_fn=CheckCache)

# %% [markdown]
# ### Part 1: API
#
# Để thu thập thông tin trang SoundCloud bằng API, ta thực hiện đi từ playlist.
#
# Ta sẽ lấy những playlist khả dụng bằng cách get trang `https://api-v2.soundcloud.com/playlists/[playlistID]?client_id=[cliend_id]` . Sau đó, ta sẽ cài đặt các hàm xử lý file json có từ những trang này để lấy thông tin của playlist, user và track tương ứng.

# %% [markdown]
# 1.1. Hàm `getEmptyPlaylist(keys)` có input:
# `keys` (kiểu dữ liệu list) , sau khi hàm được thực hiện , các trường dữ liệu của PlayList sẽ được lưu vào keys
#   Hàm được sử dụng để lấy các trường dữ liệu của Playlist , và sẽ trả về 1 dict với key là các trường dữ liệu vừa lấy được và value là 1 list trống:

# %%
def getEmptyPlaylist(keys):
    playlistID=1
    url=f'https://api-v2.soundcloud.com/playlists/{playlistID}?client_id=6gsNBd4mJwXr0LxTBh8VKBOrViK6Aj56'
    r=requests.get(url)
    playList_temp = json.loads(r.text)
    _playList=playList_temp

    #chua cac key cua playlist
    #keys=[]
    junk_keys=['embeddable_by','kind','license','permalink','sharing','uri','set_type','published_at']
    for key in junk_keys:
        _playList.pop(key,None)
    for key in playList_temp.keys():
        if key not in junk_keys:
            if key == 'id':
                keys.insert(0,key)
            else:
                keys.append(key)
    for i in keys:
        _playList[i]=[]  #tao ra mot dict rong de save du lieu ve sau
    playListID ={'id':[]}
    _playList.pop('id',None)
    _playList={**playListID, **_playList}
    
    return _playList

# %% [markdown]
# 1.2. Hàm `getEmptyUser(keys_user)` có input:
# `keys_user` (kiểu dữ liệu list) , sau khi hàm được thực hiện , các trường dữ liệu của User  sẽ được lưu vào keys_user
#   Hàm được sử dụng để lấy các trường dữ liệu của User , và sẽ trả về 1 dict với key là các trường dữ liệu vừa lấy được và value là 1 list trống

# %%
def getEmptyUser(keys_user):
    playlistID=1
    url=f'https://api-v2.soundcloud.com/playlists/{playlistID}?client_id=6gsNBd4mJwXr0LxTBh8VKBOrViK6Aj56'
    r=requests.get(url)
    playList_temp = json.loads(r.text)
    _userList=playList_temp['user']

    #chua cac key cua playlist
    #keys=[]
    junk_keys=['permalink','sharing','uri','urn','station_urn','station_permalink','kind']
    for key in junk_keys:
        _userList.pop(key,None)
    for key in playList_temp['user'].keys():
        if key not in junk_keys:
            if key == 'id':
                keys_user.insert(0,key)
            else:
                keys_user.append(key)
    for i in keys_user:
        _userList[i]=[]  #tao ra mot dict rong de save du lieu ve sau
    userListID ={'id':[]}
    _userList.pop('id',None)
    _userList={**userListID, **_userList}
    
    return _userList

# %% [markdown]
# 1.3. Hàm `getEmptyTrackt(keys_track)` có input:
# `keys_track` (kiểu dữ liệu list) , sau khi hàm được thực hiện , các trường dữ liệu của PlayList sẽ được lưu vào keys_track
#   Hàm được sử dụng để lấy các trường dữ liệu của Track , và sẽ trả về 1 dict với key là các trường dữ liệu vừa lấy được và value là 1 list trống

# %%
def getEmptyTrack(keys_track):
    playlistID=1
    url=f'https://api-v2.soundcloud.com/playlists/{playlistID}?client_id=6gsNBd4mJwXr0LxTBh8VKBOrViK6Aj56'
    r=requests.get(url)
    playList_temp = json.loads(r.text)
    _trackList=playList_temp['tracks'][0]
    
    junk_keys=['user_id','user', 'station_urn','media','waveform_url','publisher_metadata','embeddable_by','has_downloads_left','kind', 'license','permalink','sharing','uri','urn','visuals','waveform_url''station_urn','station_permalink','track_authorization','policy']
    for key in junk_keys:
        _trackList.pop(key,None)
    for key in _trackList.keys():
        if key=='id':
            keys_track.insert(0,key)
        else:
            keys_track.append(key)
    keys_track.append('mime_type')
    keys_track.append('quality')
    keys_track.append('owner')
    media={'mime_type':[],'quality':[],'owner':[]}
    _trackList={**_trackList,**media}
    for key in keys_track:
        _trackList[key]=[]
    trackID ={'id':[]}
    _trackList.pop('id',None)
    _trackList={**trackID, **_trackList}
    return _trackList

# %% [markdown]
# 1.4. Hàm `check_Exist(id , list_id)` có input:
# - `id`: là ID của User hoặc Playlist hay Track
# - `list_id` : là danh sách các id của User hoặc Playlist hay Track đã được thu thập
#
#  Để tránh trường hợp trùng lặp bộ giá trị , hàm được sử dụng để kiểm tra 1 bộ dữ liệu đã được thu thập hay chưa thông qua id , hàm trả về True hoặc False

# %%
def checkExist(value,userList):
    if value in userList:
        return True
    else:
        return False

# %% [markdown]
# 1.5. Hàm `getTrackList` có các input:
# - `playListTrack` : là dict chứa các thông tin của track có được từ playlsist
# - `_trackList`: là dict chứa các dữ liệu cần lấy cho track
# - `keys_track`: là list chứa các key cần lấy của track
#
# Sau khi thực hiện hàm, `_trackList` sẽ được thêm các dữ liệu của track lấy được

# %%
def getTrackList(playListTrack,_trackList,keys_track):
    #print(playListTrack['artwork_url'])
    for key in keys_track:
        checkNone =False
        try:
            if(str(playListTrack[key])=='None'  or str(playListTrack[key])=='NaN'or playListTrack[key]==0):
                checkNone=True
        except:
            pass
        try:
            if checkNone==False:

                if key=='mime_type':
                    mime_type=playListTrack['media']['transcodings'][0]['format']['mime_type']
                    _trackList[key].append(mime_type)
                elif key=='quality':
                    quality=playListTrack['media']['transcodings'][0]['quality']
                    _trackList[key].append(quality)
                elif key =='owner':
                    owner=playListTrack['user']['id']
                    _trackList[key].append(owner)
                else:
                    _trackList[key].append(playListTrack[key])
            else:
                _trackList[key].append('None') 
        except:
            pass

# %% [markdown]
# 1.6. Hàm `getUserList` có các input:
# - `playList` : là dict chứa các thông tin của playlsist
# - `_userList`: là dict chứa các dữ liệu cần lấy cho user
# - `keys_user`: là list chứa các key cần lấy của user
#
# Sau khi thực hiện hàm, `_userList` sẽ được thêm các dữ liệu của user lấy được

# %%
def getUserList(playList,_userList,keys_user):
    for key in keys_user:
        checkNone =False
        try:
            if(str(playList['user'][key])=='None'  or str(playList['user'][key])=='NaN'or len(playList['user'][key])==0):
                checkNone=True
        except:
            pass
        if checkNone==False:
        
            if key=='badges':
                badges=''
                for badge in playList['user'][key]:
                    #print(type(playList['user'][key][badge]))
                    if(playList['user'][key][badge]==True):
                        badges=badges+str(badge)+','
                if badges=='':
                    badges='Nonee'
                badges=badges[:-1]
                _userList[key].append(badges)
            else:
                _userList[key].append(playList['user'][key])
        else:
            _userList[key].append('None')

# %% [markdown]
# 1.7. Hàm `getPlayList` có các input:
# - `playList` : là dict chứa các thông tin của playlist
# - `_playList`: là dict chứa các dữ liệu cần lấy cho playlist
# - `keys`: là list chứa các key cần lấy của playlist
#
# Sau khi thực hiện hàm, `_playList` sẽ được thêm các dữ liệu của playlist lấy được

# %%
def getPlayList(playList,_playList,keys):
    for key in keys:
        checkNone =False
        try:
            if(str(playList[key])=='None'  or str(playList[key])=='NaN'or len(playList[key])==0):
                checkNone=True
        except:
            pass
        if checkNone==False:
            if key=='user':
                _playList[key].append(playList[key]['id'])
            elif key=='tracks':
                tracks=''
                for id in playList[key]:
                    tracks=tracks+str(id['id'])+','
                tracks = tracks[:-1]
                _playList[key].append(tracks)
            else:
                _playList[key].append(playList[key])
        else:
            _playList[key].append('None')

# %% [markdown]
# Ở một số Playlist, tồn tại một số track không có đủ thông tin cần thu thập mà chỉ có một số thông tin cơ bản.
#
# Hàm `checkKeysTrack(key_Track, list_Track)` dùng để kiếm tra xem một track có đủ thông tin cần lấy hay không.

# %%
def checkKeysTrack(key_Track, list_Track):
    for i in key_Track[0:5]:
        if i not in list_Track.keys():
            return False
    if len(list_Track['media']['transcodings'])>0:
        if 'mime_type' not in list_Track['media']['transcodings'][0]['format'].keys():
            return False
        if 'quality' not in list_Track['media']['transcodings'][0].keys():
            return False
    else:
        return False
    return True

# %% [markdown]
# Khai báo các biến
# * `keys` : là list trường dữ liệu của Playlist
# * `keys_user` : là list trường dữ liệu của User
# * `keys_track` : là list trường dữ liệu của Track
# * `_playList , _userList , _trackList :` là các dict để chứa dữ liệu của Playlist , User , Track`
# * `i` : id của 1 Playlist
# * `k` : số lượng của Playlist đã được thu thập, để kiểm soát được số lượng đã thu thập
# * `target` : số bộ giá trị tối thiểu cần đạt được khi thu thập dữ liệu
# Khởi tạo giá trị cho i là 1 , tăng i lên 1 sau mỗi lần get API và thu thập dữ liệu nếu get API thành công.   Nếu số bộ dữ liệu chưa đạt được target ta tiếp tục tăng i
#
# Chuyển các dữ liệu đã thu thập vào dataFrame và lưu vào file csv

# %%
keys=[]
_playList={}
_playList=getEmptyPlaylist(keys)
keys_user=[]
_userList={}
_userList=getEmptyUser(keys_user)
keys_track=[]
_trackList =getEmptyTrack(keys_track)
i=1
k=1
target=1000
while len(_playList['id'])<=target or len(_userList['id'])<=target or len(_trackList['id'])<=target: #or _userList<=1000 or _trackList<=1000:
    url=f'https://api-v2.soundcloud.com/playlists/{i}?client_id=6gsNBd4mJwXr0LxTBh8VKBOrViK6Aj56'
    r=requests.get(url)
    if r.ok ==True:
        print(f'Links: {i}, Lan: {k}')  # this is for testing
        
        k=k+1
        playList=json.loads(r.text)
        getPlayList(playList,_playList,keys)
        if(checkExist(playList['user']['id'],_userList['id'])==False):
            getUserList(playList,_userList,keys_user)
        #just need to get 5 out of track_count
        times=0
        if(playList['track_count']>3):
            times=3
        else:
            times=playList['track_count']
        for index in range(0,times):
            playListTrack=playList['tracks'][index]
            if(checkExist(playListTrack['id'],_trackList['id'])==False and checkKeysTrack(keys_track,playListTrack) == True):
                getTrackList(playListTrack,_trackList,keys_track)
        #Your code here
        #example
        #getUser(playList,_user,keys of user)
        #getTrack(track,_track,keys of track)
        p=len(_playList['id'])
        u=len(_userList['id'])
        t=len(_trackList['id'])
        print(f'playlist: {p}, user: {u}, tracks: {t}')
        
    i=i+1

# %% [markdown]
# Lưu thông tin playlist, user, track vào các file csv tương ứng

# %%
df1 = pd.DataFrame(_playList)
df2 = pd.DataFrame(_userList) 
df3=pd.DataFrame(_trackList)

df1.to_csv(f'./Api_data/playlist.csv',index=False,encoding='utf-8')
df2.to_csv(f'./Api_data/userlist.csv',index=False,encoding='utf-8')
df3.to_csv(f'./Api_data/tracklist.csv',index=False,encoding='utf-8')

# %% [markdown]
# ### Part 2: Parse HTML
#
# **Khai báo các set chứa các nhãn dữ liệu trong dataframe:**
#
# * `u_unorder`: là một set chứa các nhãn dữ liệu của dataframe users dựa theo thứ tự trong script ở kết quả trả về request trang web, chưa được sắp xếp thứ tự
# * `u_order`: là một set chứa các nhãn dữ liệu của dataframe users đã được sắp xếp thứ tự
# * `p_unorder`: là một set chứa các nhãn dữ liệu của dataframe playlists dựa theo thứ tự trong script ở kết quả trả về request trang web, chưa được sắp xếp thứ tự
# * `p_order`: là một set chứa các nhãn dữ liệu của dataframe playlists đã được sắp xếp thứ tự
# * `t_unorder`: là một set chứa các nhãn dữ liệu của dataframe tracks dựa theo thứ tự trong script ở kết quả trả về request trang web, chưa được sắp xếp thứ tự
# * `t_order`: là một set chứa các nhãn dữ liệu của dataframe tracks đã được sắp xếp thứ tự
#
# **Thông tin các nhãn dữ liệu:**
# * Users:
#
#     * `id`: id người dùng
#     * `username`: tên người dùng
#     * `first_name`: Tên hiển thị của người dùng
#     * `last_name`: Họ hiển thị của người dùng
#     * `full_name`: Tên hiển thị đầy đủ của người dùng
#     * `description`: Mô tả thông tin giới thiệu của người dùng
#     * `avatar_url`: đường dẫn đến avatar của người dùng
#     * `country_name`: tên quốc gia của người dùng
#     * `city`: thành phố hiện tại của người dùng
#     * `created_at`: thời gian tạo tài khoản
#     * `last_modified`: thời gian lần cuối chỉnh sửa thông tin
#     * `followers_count`: số lượng người theo dõi
#     * `followings_count`: số lượng người đang theo dõi
#     * `groups_count`: số lượng group tham gia
#     * `comments_count`: số lượng lượt bình luận nhận được
#     * `likes_count`: số lượng lượt thích nhận được
#     * `playlist_likes_count`: số lượng lượt thích của playlist do người dùng tạo
#     * `playlist_count`: số lượng playlist do người dùng tạo ra
#     * `track_count`: số lượng track do người dùng tải lên
#     * `permalink_url`: đường dẫn đến trang cá nhân của người dùng
#
# * Playlists:
#     * `id`: id của playlist
#     * `title`: tựa đề của playlist
#     * `image_playlist`: đường dẫn đến ảnh đại diện của playlist
#     * `numTracks`: số lượng track có trong playlist
#     * `description`: thông tin mô tả giới thiệu playlist
#     * `duration`: tổng thời gian các track của playlist
#     * `genre`: thể loại
#     * `label_name`: tên hãng thu playlist
#     * `tag_list`: danh sách hashtag do người dùng thêm vào
#     * `author`: tên người tạo playlist
#     * `created_at`: thời gian tạo playlist
#     * `release_date`: thời gian phát hình playlist
#     * `last_modified`: thời gian lần cuối chỉnh sửa playlist
#     * `likes_count`: số lượng lượt thích của playlist
#     * `reposts_count`: số lượng lượt được đăng lại (chia sẻ) của playlist
#     * `public`: trạng thái playlist có được truy cập công khai hay không
#     * `sharing`: trạng thái playlist có được chia sẻ hay không
#     * `trackids`: chuỗi các ID của các track có trong playlist
#     * `first_track`: đường dẫn của track đầu tiên trong playlist
#     * `permalink_url`: đường dẫn đến playlist
#
# * Tracks:
#     * `id`: id của track
#     * `title`: tựa đề của track
#     * `description`: thông tin mô tả, giới thiệu track
#     * `track_format`: hình thức của track
#     * `duration`: thời lượng track
#     * `genre`: thể loại track
#     * `label_name`: tên hãng thu track
#     * `tag_list`: danh sách hashtag người dùng thêm vào cho track
#     * `author`: tên người tạo track
#     * `created_at`: thời gian tạo
#     * `release_date`: thời gian phát hành
#     * `last_modified`: thời gian lần cuối chỉnh sửa
#     * `comment_count`: số lượng lượt bình luận
#     * `download_count`: số lượng lượt tải về
#     * `likes_count`: số lượng lượt thích
#     * `playback_count`: số lượng lượt phát/ chạy track
#     * `reposts_count`: số lượng lượt đăng lại track
#     * `state`: trạng thái của track
#     * `public`: trạng thái track có được truy cập công khai hay không
#     * `permalink_url`: đường dẫn đến track

# %%
#cài đặt hiển thị tất cả các cột
pd.set_option('display.max_columns', None)
#set các trường dữ liệu cài đặt cho dataframe lưu dữ liệu users, playlists, tracks
u_unorder=['username','country_name','avatar_url','city','comments_count','created_at','description','followers_count','followings_count','first_name','full_name','groups_count','id','last_modified','last_name','likes_count','playlist_likes_count','permalink_url','playlist_count','track_count']
u_order=['id','username','first_name','last_name','full_name','description','avatar_url','country_name','city','created_at','last_modified','followers_count','followings_count','groups_count','comments_count','likes_count','playlist_likes_count','playlist_count','track_count','permalink_url']
p_unorder=['author','image_playlist','numTracks','created_at','description','duration','genre','id','label_name','last_modified','likes_count','permalink_url','public','release_date','reposts_count','sharing','tag_list','title','trackids','first_track']
p_order=['id','title','image_playlist','description','duration','genre','label_name','tag_list','author','created_at','release_date','last_modified','likes_count','reposts_count','public','sharing','numTracks','trackids','first_track','permalink_url']
t_unorder=['comment_count','created_at','description','download_count','duration','genre', 'id', 'label_name', 'last_modified', 'likes_count','permalink_url', 'playback_count','release_date', 'reposts_count', 'tag_list','title', 'track_format','author']
t_order=['id', 'title','description','track_format','duration','genre', 'label_name', 'tag_list','author','created_at', 'release_date','last_modified', 'comment_count','download_count', 'likes_count', 'playback_count', 'reposts_count', 'permalink_url']

# %% [markdown]
# Hàm `collect_user` có các input sau:
# * `url`: là chuỗi dạng f-string cho biết đường link đến trang user cần lấy thông tin
# * `users`: là dataframe chứa thông tin của user thu thập được, gồm các nhãn dữ liệu đã được khai báo
# * Hàm này dùng để thu thập các thông tin của user thêm vào users, hàm trả về dataframe users và kết quả thu thập True, False

# %%
def collect_user(url,users):
    session = HTMLSession()
    r = session.get(url)
    if(r):
        value=[]
        soup=BeautifulSoup(r.content,features='html.parser')
        for s in (soup.find_all("script")):
            #Xét script có dữ liệu cần tìm 
            if("hydratable" in str(s)):
                #Lấy các dữ liệu trong meta
                st=str(s).find('"username"')
                en=str(s).find('",',st)
                value.append(str(s)[st+len('"username":"'):en])
                value.append(soup.find("meta", property="og:country-name").get('content'))
                #Cắt chuỗi trong script
                i=str(s).find('{"hydratable":"user","')
                j=str(s).find('"uri"')
                s=str(s)[i+len('{"hydratable":"user","data":{'):j-1]
                #Cắt chuỗi thành một mảng gồm nhiều trường dữ liệu
                r1 = re.split(r',"',s)
                for i in r1:
                    t=re.split(r'":',i)
                    #Với mỗi phần tử là trường dữ liệu tồn tại trong dataframe, thêm vào mảng tạm value theo thứ tự
                    if(t[0].strip('"') in list(users)):
                        #Nếu t được cắt thành 2 phần tử thì thêm t[1] là giá trị vào value
                        #Nếu t được cắt thành 1 trường dữ liệu t[0] là tên của trường dữ liệu, thêm null vào value
                        #Ngược lại, nếu t rỗng thì bỏ qua
                        if(len(t)==2):
                            value.append(t[1].strip('"'))
                        elif(t[0]):
                            value.append('null')
                #Xét điều kiện kích thước của value bằng số lượng các cột của users thì thêm dữ liệu vào users
                if(len(value)==len(list(users))):
                    zipped = zip(list(users), value)
                    u = dict(zipped)
                    users=users.append(u,ignore_index=True)
                    return users, True
    return users, False

# %% [markdown]
# Hàm `collect_playlist` có các input sau:
# * `url`: là chuỗi dạng f-string, cho biết đường link đến trang playlist cần lấy thông tin
# * `playlists`: là dataframe chứa thông tin của playlist thu thập được, gồm các nhãn dữ liệu đã được khai báo
# * Hàm này dùng để thu thập các thông tin của playlist thêm vào playlists, hàm trả về dataframe playlists và kết quả thu thập True, False

# %%
def collect_playlist(url,playlists):
    session = HTMLSession()
    r = session.get(url) 
    if(r):
        value=[]
        soup = BeautifulSoup(r.content,features="html.parser")
        for s in (soup.find_all("script")):
            #Xét script có dữ liệu cần tìm 
            if("hydratable" in str(s)):
                #Lấy các dữ liệu trong meta
                value.append(soup.find("meta",itemprop="name").get('content'))
                value.append(soup.find("meta", property="og:image").get('content'))
                value.append(soup.find("meta", itemprop="numTracks").get('content'))
                #Cắt chuỗi trong script
                i=str(s).find('{"hydratable":"playlist"')
                s=str(s)[i+len('{"hydratable":"playlist","data":{'):]
                j=s.find('"uri"')
                s1=s[:j-1]
                s2=s[str(s).find('"tracks":[{')+len('"tracks":[{'):]
                #Cắt chuỗi thành một mảng gồm nhiều trường dữ liệu
                r1 = re.split(r',"',s1)
                for i in r1:
                    t=re.split(r'":',i)
                    #Với mỗi phần tử là trường dữ liệu tồn tại trong dataframe, thêm vào mảng tạm value theo thứ tự
                    if(t[0].strip('"') in list(playlists)):
                        #Nếu t được cắt thành 2 phần tử thì thêm t[1] là giá trị vào value
                        if(len(t)==2): 
                            value.append(t[1].strip('"'))
                trackids="'"
                for k in range(min(5,int(value[2]))):
                    s2=s2[str(s2).find('"id":')+len('"id":'):]
                    end=str(s2).find(',"')
                    trackids = trackids + s2[:end]
                    if(k!=int(value[2])-1): 
                        trackids=trackids+","
                for k in range(0,int(value[2])-5):
                    s2=s2[str(s2).find('{"id":')+len('{"id":'):]
                    end=str(s2).find(',"')
                    trackids = trackids + s2[:end]
                    if(k!=int(value[2])-5-1): 
                        trackids=trackids+','
                trackids=trackids+"'"
                value.append(str(trackids))
                #Lấy thêm link track đầu tiên trong playlist
                value.append(f'https://soundcloud.com' + soup.find('h2',itemprop ='name').find('a',itemprop="url").get('href'))
                #Xét điều kiện kích thước của value bằng số lượng các cột của playlist thì thêm dữ liệu vào playlists
                if(len(value)==len(list(playlists))):
                    zipped = zip(list(playlists), value)
                    p = dict(zipped)
                    playlists=playlists.append(p,ignore_index=True)
                    return playlists, True
    return playlists, False

# %% [markdown]
# Hàm `collect_track` có các input sau:
# * `url`: là chuỗi dạng f-string, cho biết đường link đến trang track cần lấy thông tin
# * `tracks`: là dataframe chứa thông tin của track thu thập được, gồm các nhãn dữ liệu đã được khai báo
# * Hàm này dùng để thu thập các thông tin của track thêm vào tracks, hàm trả về dataframe tracks và kết quả thu thập True, False

# %%
def collect_track(url, tracks):
    session = HTMLSession()
    r = session.get(url)
    if(r):
        soup = BeautifulSoup(r.content,features="html.parser")
        value=[]
        for s in (soup.find_all("script")):
            #Xét script có dữ liệu cần tìm 
            if("hydratable" in str(s)):
                #Cắt chuỗi trong script
                i=str(s).find('{"hydratable":"sound"')
                s=str(s)[i+len('{"hydratable":"sound","data":{'):]
                j=s.find('"uri"')
                s=s[:j-1]
                #Cắt chuỗi thành một mảng gồm nhiều trường dữ liệu
                r1 = re.split(r',"',s)
                for i in r1:
                    #Với mỗi phần tử là trường dữ liệu tồn tại trong dataframe, thêm vào mảng tạm value theo thứ tự
                    t=re.split(r'":',i)
                    if(t[0].strip('"')=='id' and t[1].strip('"') in list(tracks['id'])):
                        return tracks, False 
                    if(t[0].strip('"') in list(tracks)): 
                        value.append(t[1].strip('"'))
                #Lấy thêm thông tin người đăng track
                author =  soup.find("link",rel="author")
                if (author):
                    author = (author.get('href')).replace('/','')
                value.append(author)
                #Xét điều kiện kích thước của value bằng số lượng các cột của tracks thì thêm dữ liệu vào tracks
                if(len(value)==len(list(tracks))):
                    zipped = zip(list(tracks), value)
                    p = dict(zipped)
                    tracks=tracks.append(p,ignore_index=True)
                    return tracks, True
    return tracks,False

# %% [markdown]
# Hàm `collect_all` có các input sau:
# * `users`: là dataframe chứa thông tin của user thu thập được, gồm các nhãn dữ liệu đã được khai báo
# * `playlists`: là dataframe chứa thông tin của playlist thu thập được, gồm các nhãn dữ liệu đã được khai báo
# * `tracks`: là dataframe chứa thông tin của track thu thập được, gồm các nhãn dữ liệu đã được khai báo
# * `users_file`: là chuỗi, cho biết tên của file output dạng csv lưu thông tin users sau khi thu thập từ trang web
# * `playlists_file`: là chuỗi, cho biết tên của file output dạng csv lưu thông tin playlists sau khi thu thập từ trang web
# * `tracks_file`: là chuỗi, cho biết tên của file output dạng csv lưu thông tin tracks sau khi thu thập từ trang web
# Hàm này dùng để gọi lại các hàm `collect_user`, `collect_playlist`, `collect_track` để thu thập các dữ liệu cần thiết và lưu vào các dataframe có tên tương ứng là `users`, `playlists`, `tracks` được khai báo trong hàm.Trong quá trình thu thập dữ liệu, hàm sẽ in ra số lượng dữ liệu đã thu thập. Sau khi kết thúc quá trình thu thập, hàm trả về các dataframe sẽ được sắp xếp lại các cột dữ liệu để rõ ràng hơn đồng thời cũng lưu vào file output với các thông tin tương ứng là các nhãn dữ liệu của các dataframe trên.

# %%
def collect_all(users_file, playlists_file, tracks_file,users,playlists,tracks):
    url = f'https://soundcloud.com/'
    index = 1002
    count_u = 0
    count_p = 0
    count_t = 0
    while (True):
        try:
            u_url=url+str(index)
            session = HTMLSession()
            u = session.get(u_url)
            if(u): 
                p_url = u_url+'/sets'
                session = HTMLSession()
                p=session.get(p_url) 
                #Lấy link playlists trong trang user hiện tại
                if(p.html.find('.audible', first=True)):
                    p_urls = p.html.find('.audible', first=True).absolute_links
                    for link in p_urls:
                        if('sets/' in link):
                            p_url=link
                            break
                    session = HTMLSession()
                    t = session.get(p_url)
                    t_soup=BeautifulSoup(t.content,features="html.parser")
                    try:
                        #Lấy link track đầu tiên trong playlist nếu có
                        t_url=f'https://soundcloud.com' + t_soup.find('h2',itemprop ='name').find('a',itemprop="url").get('href')
                        tracks, check_t=collect_track(t_url,tracks)
                        playlists, check_p=collect_playlist(p_url,playlists)
                        users, check_u=collect_user(u_url,users)
                        #Tăng biến đếm
                        if (check_u==True): count_u=count_u+1 
                        if (check_p==True): count_p=count_p+1 
                        if (check_t==True): count_t=count_t+1 
                        print('users:',count_u,'playlists:',count_p,'tracks:',count_t)
                        #Xuất số lượng các bộ dữ liệu đã thu thập được ở hiện tại ra màn hình
                    except:
                        index=index+1
                        continue 
            index=index+1
            #dieu kien dung
            num=1000
            if(count_u>num and count_p>num and count_t>num): break
        except:
            time.sleep(1)
    #Sắp xếp lại các cột dữ liệu trong dataframe
    users=users[u_order]
    playlists=playlists[p_order]
    tracks=tracks[t_order]
    #Ghi dữ liệu ở dataframe vào file
    users.to_csv(users_file,index=False)
    playlists.to_csv(playlists_file,index=False)
    tracks.to_csv(tracks_file,index=False)
    return users, playlists, tracks

# %% [markdown]
# **Lưu thông tin thu thập được vào các file csv tương ứng:**

# %%
#Khởi tạo DataFrame 
users=pd.DataFrame(columns=u_unorder)
playlists = pd.DataFrame(columns=p_unorder)
tracks=pd.DataFrame(columns=t_unorder)
#Thu thập dữ liệu và ghi vào file
users,playlists,tracks=collect_all('./Crawl_data/users.csv','./Crawl_data/playlists.csv','./Crawl_data/tracks.csv',users,playlists,tracks)
# Out:
# users: 1 playlists: 1 tracks: 1
# users: 2 playlists: 2 tracks: 2
# users: 3 playlists: 3 tracks: 3
# users: 4 playlists: 4 tracks: 4
# users: 5 playlists: 5 tracks: 5
# users: 6 playlists: 6 tracks: 6
# users: 7 playlists: 7 tracks: 7
# users: 8 playlists: 8 tracks: 8
# users: 9 playlists: 9 tracks: 9
# users: 10 playlists: 10 tracks: 10
# users: 11 playlists: 11 tracks: 11
# users: 12 playlists: 12 tracks: 12
# users: 13 playlists: 13 tracks: 13
# users: 14 playlists: 14 tracks: 14
# users: 15 playlists: 15 tracks: 15
# users: 16 playlists: 16 tracks: 16
# users: 17 playlists: 17 tracks: 17
# users: 18 playlists: 18 tracks: 18
# users: 19 playlists: 19 tracks: 19
# users: 20 playlists: 20 tracks: 20
# users: 21 playlists: 21 tracks: 21
# users: 22 playlists: 22 tracks: 22
# users: 23 playlists: 23 tracks: 23
# users: 24 playlists: 24 tracks: 24
# users: 25 playlists: 25 tracks: 25
# users: 26 playlists: 26 tracks: 26
# users: 27 playlists: 27 tracks: 27
# users: 28 playlists: 28 tracks: 28
# users: 29 playlists: 29 tracks: 29
# users: 30 playlists: 30 tracks: 30
# users: 31 playlists: 31 tracks: 31
# users: 32 playlists: 32 tracks: 32
# users: 33 playlists: 33 tracks: 33
# users: 34 playlists: 34 tracks: 34
# users: 35 playlists: 35 tracks: 35
# users: 36 playlists: 36 tracks: 36
# users: 37 playlists: 37 tracks: 37
# users: 38 playlists: 38 tracks: 38
# users: 39 playlists: 39 tracks: 39
# users: 40 playlists: 40 tracks: 40
# users: 41 playlists: 41 tracks: 41
# users: 42 playlists: 42 tracks: 42
# users: 43 playlists: 43 tracks: 43
# users: 44 playlists: 44 tracks: 44
# users: 45 playlists: 45 tracks: 45
# users: 46 playlists: 46 tracks: 46
# users: 47 playlists: 47 tracks: 47
# users: 48 playlists: 48 tracks: 48
# users: 49 playlists: 49 tracks: 49
# users: 50 playlists: 50 tracks: 50
# users: 51 playlists: 51 tracks: 51
# users: 52 playlists: 52 tracks: 52
# users: 53 playlists: 53 tracks: 53
# users: 54 playlists: 54 tracks: 54
# users: 55 playlists: 55 tracks: 55
# users: 56 playlists: 56 tracks: 56
# users: 57 playlists: 57 tracks: 57
# users: 58 playlists: 58 tracks: 58
# users: 59 playlists: 59 tracks: 59
# users: 60 playlists: 60 tracks: 60
# users: 61 playlists: 61 tracks: 61
# users: 62 playlists: 62 tracks: 62
# users: 63 playlists: 63 tracks: 63
# users: 64 playlists: 64 tracks: 64
# users: 65 playlists: 65 tracks: 65
# users: 66 playlists: 66 tracks: 66
# users: 67 playlists: 67 tracks: 67
# users: 68 playlists: 68 tracks: 68
# users: 69 playlists: 69 tracks: 69
# users: 70 playlists: 70 tracks: 70
# users: 71 playlists: 71 tracks: 71
# users: 72 playlists: 72 tracks: 72
# users: 73 playlists: 73 tracks: 73
# users: 74 playlists: 74 tracks: 74
# users: 75 playlists: 75 tracks: 75
# users: 76 playlists: 76 tracks: 76
# users: 77 playlists: 77 tracks: 77
# users: 78 playlists: 78 tracks: 78
# users: 79 playlists: 79 tracks: 79
# users: 80 playlists: 80 tracks: 80
# users: 81 playlists: 81 tracks: 81
# users: 82 playlists: 82 tracks: 82
# users: 83 playlists: 83 tracks: 83
# users: 84 playlists: 84 tracks: 84
# users: 85 playlists: 85 tracks: 85
# users: 86 playlists: 86 tracks: 86
# users: 87 playlists: 87 tracks: 87
# users: 88 playlists: 88 tracks: 88
# users: 89 playlists: 89 tracks: 89
# users: 90 playlists: 90 tracks: 90
# users: 91 playlists: 91 tracks: 91
# users: 92 playlists: 92 tracks: 92
# users: 93 playlists: 93 tracks: 93
# users: 94 playlists: 94 tracks: 94
# users: 95 playlists: 95 tracks: 95
# users: 96 playlists: 96 tracks: 96
# users: 97 playlists: 97 tracks: 97
# users: 98 playlists: 98 tracks: 98
# users: 99 playlists: 99 tracks: 99
# users: 100 playlists: 100 tracks: 100
# users: 101 playlists: 101 tracks: 101
# users: 102 playlists: 102 tracks: 102
# users: 103 playlists: 103 tracks: 103
# users: 104 playlists: 104 tracks: 104
# users: 105 playlists: 105 tracks: 105
# users: 106 playlists: 106 tracks: 106
# users: 107 playlists: 107 tracks: 107
# users: 108 playlists: 108 tracks: 108
# users: 109 playlists: 109 tracks: 109
# users: 110 playlists: 110 tracks: 110
# users: 111 playlists: 111 tracks: 111
# users: 112 playlists: 112 tracks: 112
# users: 113 playlists: 113 tracks: 113
# users: 114 playlists: 114 tracks: 114
# users: 115 playlists: 115 tracks: 115
# users: 116 playlists: 116 tracks: 116
# users: 117 playlists: 117 tracks: 117
# users: 118 playlists: 118 tracks: 118
# users: 119 playlists: 119 tracks: 119
# users: 120 playlists: 120 tracks: 120
# users: 197 playlists: 197 tracks: 197
# users: 198 playlists: 198 tracks: 198
# users: 199 playlists: 199 tracks: 199
# users: 200 playlists: 200 tracks: 200
# users: 201 playlists: 201 tracks: 201
# users: 202 playlists: 202 tracks: 202
# users: 203 playlists: 203 tracks: 203
# users: 204 playlists: 204 tracks: 204
# users: 205 playlists: 205 tracks: 205
# users: 206 playlists: 206 tracks: 206
# users: 207 playlists: 207 tracks: 207
# users: 208 playlists: 208 tracks: 208
# users: 209 playlists: 209 tracks: 209
# users: 210 playlists: 210 tracks: 210
# users: 211 playlists: 211 tracks: 211
# users: 212 playlists: 212 tracks: 212
# users: 213 playlists: 213 tracks: 213
# users: 214 playlists: 214 tracks: 214
# users: 215 playlists: 215 tracks: 215
# users: 216 playlists: 216 tracks: 216
# users: 217 playlists: 217 tracks: 217
# users: 218 playlists: 218 tracks: 218
# users: 219 playlists: 219 tracks: 219
# users: 220 playlists: 220 tracks: 220
# users: 221 playlists: 221 tracks: 221
# users: 222 playlists: 222 tracks: 222
# users: 223 playlists: 223 tracks: 223
# users: 224 playlists: 224 tracks: 224
# users: 225 playlists: 225 tracks: 225
# users: 226 playlists: 226 tracks: 226
# users: 227 playlists: 227 tracks: 227
# users: 228 playlists: 228 tracks: 228
# users: 229 playlists: 229 tracks: 229
# users: 230 playlists: 230 tracks: 230
# users: 231 playlists: 231 tracks: 231
# users: 232 playlists: 232 tracks: 232
# users: 233 playlists: 233 tracks: 233
# users: 234 playlists: 234 tracks: 234
# users: 235 playlists: 235 tracks: 235
# users: 236 playlists: 236 tracks: 236
# users: 237 playlists: 237 tracks: 237
# users: 238 playlists: 238 tracks: 238
# users: 239 playlists: 239 tracks: 239
# users: 240 playlists: 240 tracks: 240
# users: 241 playlists: 241 tracks: 241
# users: 242 playlists: 242 tracks: 242
# users: 243 playlists: 243 tracks: 243
# users: 244 playlists: 244 tracks: 244
# users: 245 playlists: 245 tracks: 245
# users: 246 playlists: 246 tracks: 246
# users: 247 playlists: 247 tracks: 247
# users: 248 playlists: 248 tracks: 248
# users: 249 playlists: 249 tracks: 249
# users: 250 playlists: 250 tracks: 250
# users: 251 playlists: 251 tracks: 251
# users: 252 playlists: 252 tracks: 252
# users: 253 playlists: 253 tracks: 253
# users: 254 playlists: 254 tracks: 254
# users: 255 playlists: 255 tracks: 255
# users: 256 playlists: 256 tracks: 256
# users: 257 playlists: 257 tracks: 257
# users: 258 playlists: 258 tracks: 258
# users: 259 playlists: 259 tracks: 259
# users: 260 playlists: 260 tracks: 260
# users: 261 playlists: 261 tracks: 261
# users: 262 playlists: 262 tracks: 262
# users: 263 playlists: 263 tracks: 263
# users: 264 playlists: 264 tracks: 264
# users: 265 playlists: 265 tracks: 265
# users: 266 playlists: 266 tracks: 266
# users: 267 playlists: 267 tracks: 267
# users: 268 playlists: 268 tracks: 268
# users: 269 playlists: 269 tracks: 269
# users: 270 playlists: 270 tracks: 270
# users: 271 playlists: 271 tracks: 271
# users: 272 playlists: 272 tracks: 272
# users: 501 playlists: 500 tracks: 500
# users: 502 playlists: 501 tracks: 501
# users: 503 playlists: 502 tracks: 502
# users: 504 playlists: 503 tracks: 503
# users: 505 playlists: 504 tracks: 504
# users: 506 playlists: 505 tracks: 505
# users: 507 playlists: 506 tracks: 506
# users: 508 playlists: 507 tracks: 507
# users: 509 playlists: 508 tracks: 508
# users: 510 playlists: 509 tracks: 509
# users: 511 playlists: 510 tracks: 510
# users: 512 playlists: 511 tracks: 511
# users: 513 playlists: 512 tracks: 512
# users: 514 playlists: 513 tracks: 513
# users: 515 playlists: 514 tracks: 514
# users: 516 playlists: 515 tracks: 515
# users: 517 playlists: 516 tracks: 516
# users: 518 playlists: 517 tracks: 517
# users: 519 playlists: 518 tracks: 518
# users: 520 playlists: 519 tracks: 519
# users: 521 playlists: 520 tracks: 520
# users: 522 playlists: 521 tracks: 521
# users: 523 playlists: 522 tracks: 522
# users: 524 playlists: 523 tracks: 523
# users: 525 playlists: 524 tracks: 524
# users: 526 playlists: 525 tracks: 525
# users: 527 playlists: 526 tracks: 526
# users: 528 playlists: 527 tracks: 527
# users: 529 playlists: 528 tracks: 528
# users: 530 playlists: 529 tracks: 529
# users: 531 playlists: 530 tracks: 530
# users: 532 playlists: 531 tracks: 531
# users: 533 playlists: 532 tracks: 531
# users: 534 playlists: 533 tracks: 532
# users: 535 playlists: 534 tracks: 533
# users: 536 playlists: 535 tracks: 534
# users: 537 playlists: 536 tracks: 535
# users: 538 playlists: 537 tracks: 536
# users: 539 playlists: 538 tracks: 537
# users: 540 playlists: 539 tracks: 538
# users: 541 playlists: 540 tracks: 539
# users: 542 playlists: 541 tracks: 540
# users: 543 playlists: 542 tracks: 541
# users: 544 playlists: 543 tracks: 542
# users: 545 playlists: 544 tracks: 543
# users: 546 playlists: 545 tracks: 544
# users: 547 playlists: 546 tracks: 545
# users: 548 playlists: 547 tracks: 546
# users: 549 playlists: 548 tracks: 547
# users: 550 playlists: 549 tracks: 548
# users: 551 playlists: 550 tracks: 549
# users: 552 playlists: 551 tracks: 550
# users: 553 playlists: 552 tracks: 551
# users: 554 playlists: 553 tracks: 552
# users: 555 playlists: 554 tracks: 553
# users: 556 playlists: 555 tracks: 554
# users: 557 playlists: 556 tracks: 554
# users: 558 playlists: 557 tracks: 555
# users: 559 playlists: 558 tracks: 556
# users: 560 playlists: 559 tracks: 557
# users: 561 playlists: 560 tracks: 558
# users: 562 playlists: 561 tracks: 559
# users: 563 playlists: 562 tracks: 560
# users: 564 playlists: 563 tracks: 561
# users: 565 playlists: 564 tracks: 562
# users: 566 playlists: 565 tracks: 563
# users: 567 playlists: 566 tracks: 564
# users: 568 playlists: 567 tracks: 565
# users: 569 playlists: 568 tracks: 566
# users: 570 playlists: 569 tracks: 567
# users: 571 playlists: 570 tracks: 568
# users: 572 playlists: 571 tracks: 569
# users: 573 playlists: 572 tracks: 570
# users: 574 playlists: 573 tracks: 571
# users: 575 playlists: 574 tracks: 571
# users: 576 playlists: 575 tracks: 572
# users: 577 playlists: 576 tracks: 573
# users: 578 playlists: 577 tracks: 574
# users: 579 playlists: 578 tracks: 575
# users: 580 playlists: 579 tracks: 576
# users: 581 playlists: 580 tracks: 577
# users: 582 playlists: 581 tracks: 578
# users: 583 playlists: 582 tracks: 579
# users: 584 playlists: 583 tracks: 580
# users: 585 playlists: 584 tracks: 580
# users: 586 playlists: 585 tracks: 581
# users: 587 playlists: 586 tracks: 582
# users: 588 playlists: 587 tracks: 583
# users: 589 playlists: 588 tracks: 584
# users: 590 playlists: 589 tracks: 585
# users: 591 playlists: 590 tracks: 586
# users: 592 playlists: 591 tracks: 587
# users: 593 playlists: 592 tracks: 588
# users: 594 playlists: 593 tracks: 589
# users: 595 playlists: 594 tracks: 590
# users: 596 playlists: 595 tracks: 591
# users: 597 playlists: 596 tracks: 592
# users: 598 playlists: 597 tracks: 593
# users: 599 playlists: 598 tracks: 594
# users: 600 playlists: 599 tracks: 595
# users: 601 playlists: 600 tracks: 596
# users: 602 playlists: 601 tracks: 597
# users: 603 playlists: 602 tracks: 598
# users: 604 playlists: 603 tracks: 599
# users: 605 playlists: 604 tracks: 600
# users: 606 playlists: 605 tracks: 601
# users: 607 playlists: 606 tracks: 602
# users: 608 playlists: 607 tracks: 603
# users: 609 playlists: 608 tracks: 604
# users: 610 playlists: 609 tracks: 605
# users: 611 playlists: 610 tracks: 606
# users: 612 playlists: 611 tracks: 607
# users: 613 playlists: 612 tracks: 608
# users: 614 playlists: 613 tracks: 609
# users: 615 playlists: 614 tracks: 610
# users: 616 playlists: 615 tracks: 611
# users: 617 playlists: 616 tracks: 612
# users: 618 playlists: 617 tracks: 613
# users: 619 playlists: 618 tracks: 614
# users: 620 playlists: 619 tracks: 615
# users: 621 playlists: 620 tracks: 616
# users: 622 playlists: 621 tracks: 617
# users: 623 playlists: 622 tracks: 618
# users: 624 playlists: 623 tracks: 619
# users: 625 playlists: 624 tracks: 620
# users: 626 playlists: 625 tracks: 621
# users: 627 playlists: 626 tracks: 622
# users: 628 playlists: 627 tracks: 623
# users: 629 playlists: 628 tracks: 624
# users: 630 playlists: 629 tracks: 625
# users: 631 playlists: 630 tracks: 626
# users: 632 playlists: 631 tracks: 627
# users: 633 playlists: 632 tracks: 628
# users: 634 playlists: 633 tracks: 629
# users: 635 playlists: 634 tracks: 630
# users: 636 playlists: 635 tracks: 631
# users: 637 playlists: 636 tracks: 632
# users: 638 playlists: 637 tracks: 633
# users: 639 playlists: 638 tracks: 634
# users: 640 playlists: 639 tracks: 635
# users: 641 playlists: 640 tracks: 636
# users: 642 playlists: 641 tracks: 637
# users: 643 playlists: 642 tracks: 638
# users: 644 playlists: 643 tracks: 639
# users: 645 playlists: 644 tracks: 640
# users: 646 playlists: 645 tracks: 641
# users: 647 playlists: 646 tracks: 642
# users: 648 playlists: 647 tracks: 643
# users: 649 playlists: 648 tracks: 644
# users: 650 playlists: 649 tracks: 645
# users: 651 playlists: 650 tracks: 646
# users: 652 playlists: 651 tracks: 647
# users: 653 playlists: 652 tracks: 648
# users: 654 playlists: 653 tracks: 649
# users: 655 playlists: 654 tracks: 650
# users: 656 playlists: 655 tracks: 651
# users: 657 playlists: 656 tracks: 652
# users: 658 playlists: 657 tracks: 653
# users: 659 playlists: 658 tracks: 654
# users: 660 playlists: 659 tracks: 654
# users: 661 playlists: 660 tracks: 655
# users: 662 playlists: 661 tracks: 656
# users: 663 playlists: 662 tracks: 657
# users: 664 playlists: 663 tracks: 658
# users: 665 playlists: 664 tracks: 659
# users: 666 playlists: 665 tracks: 660
# users: 667 playlists: 666 tracks: 661
# users: 668 playlists: 667 tracks: 662
# users: 669 playlists: 668 tracks: 663
# users: 670 playlists: 669 tracks: 664
# users: 671 playlists: 670 tracks: 665
# users: 672 playlists: 671 tracks: 666
# users: 673 playlists: 672 tracks: 667
# users: 674 playlists: 673 tracks: 668
# users: 675 playlists: 674 tracks: 669
# users: 676 playlists: 675 tracks: 670
# users: 677 playlists: 676 tracks: 671
# users: 678 playlists: 677 tracks: 672
# users: 679 playlists: 678 tracks: 673
# users: 680 playlists: 679 tracks: 674
# users: 681 playlists: 680 tracks: 675
# users: 682 playlists: 681 tracks: 676
# users: 683 playlists: 682 tracks: 677
# users: 684 playlists: 683 tracks: 678
# users: 685 playlists: 684 tracks: 679
# users: 686 playlists: 685 tracks: 680
# users: 687 playlists: 686 tracks: 681
# users: 688 playlists: 687 tracks: 682
# users: 689 playlists: 688 tracks: 683
# users: 690 playlists: 689 tracks: 684
# users: 691 playlists: 690 tracks: 685
# users: 692 playlists: 691 tracks: 686
# users: 693 playlists: 692 tracks: 687
# users: 694 playlists: 693 tracks: 688
# users: 695 playlists: 694 tracks: 689
# users: 696 playlists: 695 tracks: 690
# users: 697 playlists: 696 tracks: 691
# users: 698 playlists: 697 tracks: 692
# users: 699 playlists: 698 tracks: 693
# users: 700 playlists: 699 tracks: 694
# users: 701 playlists: 700 tracks: 695
# users: 702 playlists: 701 tracks: 696
# users: 703 playlists: 702 tracks: 697
# users: 704 playlists: 703 tracks: 698
# users: 705 playlists: 704 tracks: 699
# users: 706 playlists: 705 tracks: 700
# users: 707 playlists: 706 tracks: 701
# users: 708 playlists: 707 tracks: 702
# users: 709 playlists: 708 tracks: 703
# users: 710 playlists: 709 tracks: 704
# users: 711 playlists: 710 tracks: 705
# users: 712 playlists: 711 tracks: 706
# users: 713 playlists: 712 tracks: 707
# users: 714 playlists: 713 tracks: 708
# users: 715 playlists: 714 tracks: 709
# users: 716 playlists: 715 tracks: 710
# users: 717 playlists: 716 tracks: 711
# users: 718 playlists: 717 tracks: 712
# users: 719 playlists: 718 tracks: 713
# users: 720 playlists: 719 tracks: 714
# users: 721 playlists: 720 tracks: 715
# users: 722 playlists: 721 tracks: 716
# users: 723 playlists: 722 tracks: 717
# users: 724 playlists: 723 tracks: 718
# users: 725 playlists: 724 tracks: 719
# users: 726 playlists: 725 tracks: 720
# users: 727 playlists: 726 tracks: 721
# users: 728 playlists: 727 tracks: 722
# users: 729 playlists: 728 tracks: 723
# users: 730 playlists: 729 tracks: 724
# users: 731 playlists: 730 tracks: 725
# users: 732 playlists: 731 tracks: 726
# users: 733 playlists: 732 tracks: 727
# users: 734 playlists: 733 tracks: 728
# users: 735 playlists: 734 tracks: 729
# users: 736 playlists: 735 tracks: 730
# users: 737 playlists: 736 tracks: 731
# users: 738 playlists: 737 tracks: 732
# users: 739 playlists: 738 tracks: 733
# users: 740 playlists: 739 tracks: 734
# users: 741 playlists: 740 tracks: 735
# users: 742 playlists: 741 tracks: 736
# users: 743 playlists: 742 tracks: 737
# users: 744 playlists: 743 tracks: 738
# users: 745 playlists: 744 tracks: 739
# users: 746 playlists: 745 tracks: 740
# users: 747 playlists: 746 tracks: 741
# users: 748 playlists: 747 tracks: 742
# users: 749 playlists: 748 tracks: 743
# users: 750 playlists: 749 tracks: 744
# users: 751 playlists: 750 tracks: 745
# users: 752 playlists: 751 tracks: 746
# users: 753 playlists: 752 tracks: 747
# users: 754 playlists: 753 tracks: 748
# users: 755 playlists: 754 tracks: 749
# users: 756 playlists: 755 tracks: 750
# users: 757 playlists: 756 tracks: 751
# users: 758 playlists: 757 tracks: 752
# users: 759 playlists: 758 tracks: 753
# users: 760 playlists: 759 tracks: 754
# users: 761 playlists: 760 tracks: 755
# users: 762 playlists: 761 tracks: 756
# users: 763 playlists: 762 tracks: 757
# users: 764 playlists: 763 tracks: 758
# users: 765 playlists: 764 tracks: 759
# users: 766 playlists: 765 tracks: 760
# users: 767 playlists: 766 tracks: 761
# users: 768 playlists: 767 tracks: 762
# users: 769 playlists: 768 tracks: 763
# users: 770 playlists: 769 tracks: 764
# users: 771 playlists: 770 tracks: 765
# users: 772 playlists: 771 tracks: 766
# users: 773 playlists: 772 tracks: 767
# users: 774 playlists: 773 tracks: 768
# users: 775 playlists: 774 tracks: 769
# users: 776 playlists: 775 tracks: 770
# users: 777 playlists: 776 tracks: 771
# users: 778 playlists: 777 tracks: 772
# users: 779 playlists: 778 tracks: 773
# users: 780 playlists: 779 tracks: 774
# users: 781 playlists: 780 tracks: 775
# users: 782 playlists: 781 tracks: 776
# users: 783 playlists: 782 tracks: 777
# users: 784 playlists: 783 tracks: 778
# users: 785 playlists: 784 tracks: 779
# users: 786 playlists: 785 tracks: 780
# users: 787 playlists: 786 tracks: 781
# users: 788 playlists: 787 tracks: 782
# users: 789 playlists: 788 tracks: 783
# users: 790 playlists: 789 tracks: 784
# users: 791 playlists: 790 tracks: 785
# users: 792 playlists: 791 tracks: 786
# users: 793 playlists: 792 tracks: 787
# users: 794 playlists: 793 tracks: 788
# users: 795 playlists: 794 tracks: 789
# users: 796 playlists: 795 tracks: 790
# users: 797 playlists: 796 tracks: 791
# users: 798 playlists: 797 tracks: 792
# users: 799 playlists: 798 tracks: 793
# users: 800 playlists: 799 tracks: 794
# users: 801 playlists: 800 tracks: 795
# users: 802 playlists: 801 tracks: 796
# users: 803 playlists: 802 tracks: 797
# users: 804 playlists: 803 tracks: 798
# users: 805 playlists: 804 tracks: 799
# users: 806 playlists: 805 tracks: 800
# users: 807 playlists: 806 tracks: 801
# users: 808 playlists: 807 tracks: 802
# users: 809 playlists: 808 tracks: 803
# users: 810 playlists: 809 tracks: 804
# users: 811 playlists: 810 tracks: 805
# users: 812 playlists: 811 tracks: 806
# users: 813 playlists: 812 tracks: 807
# users: 814 playlists: 813 tracks: 808
# users: 815 playlists: 814 tracks: 809
# users: 816 playlists: 815 tracks: 810
# users: 817 playlists: 816 tracks: 811
# users: 818 playlists: 817 tracks: 812
# users: 819 playlists: 818 tracks: 813
# users: 820 playlists: 819 tracks: 814
# users: 821 playlists: 820 tracks: 815
# users: 822 playlists: 821 tracks: 816
# users: 823 playlists: 822 tracks: 817
# users: 824 playlists: 823 tracks: 818
# users: 825 playlists: 824 tracks: 819
# users: 826 playlists: 825 tracks: 820
# users: 827 playlists: 826 tracks: 821
# users: 828 playlists: 827 tracks: 822
# users: 829 playlists: 828 tracks: 823
# users: 830 playlists: 829 tracks: 824
# users: 831 playlists: 830 tracks: 825
# users: 832 playlists: 831 tracks: 826
# users: 833 playlists: 832 tracks: 827
# users: 834 playlists: 833 tracks: 828
# users: 835 playlists: 834 tracks: 829
# users: 836 playlists: 835 tracks: 830
# users: 837 playlists: 836 tracks: 831
# users: 838 playlists: 837 tracks: 832
# users: 839 playlists: 838 tracks: 833
# users: 840 playlists: 839 tracks: 834
# users: 841 playlists: 840 tracks: 835
# users: 842 playlists: 841 tracks: 836
# users: 843 playlists: 842 tracks: 837
# users: 844 playlists: 843 tracks: 838
# users: 845 playlists: 844 tracks: 839
# users: 846 playlists: 845 tracks: 840
# users: 847 playlists: 846 tracks: 841
# users: 848 playlists: 847 tracks: 842
# users: 849 playlists: 848 tracks: 843
# users: 850 playlists: 849 tracks: 844
# users: 851 playlists: 850 tracks: 845
# users: 852 playlists: 851 tracks: 846
# users: 853 playlists: 852 tracks: 847
# users: 854 playlists: 853 tracks: 848
# users: 855 playlists: 854 tracks: 849
# users: 856 playlists: 855 tracks: 850
# users: 857 playlists: 856 tracks: 851
# users: 858 playlists: 857 tracks: 852
# users: 859 playlists: 858 tracks: 853
# users: 860 playlists: 859 tracks: 854
# users: 861 playlists: 860 tracks: 855
# users: 862 playlists: 861 tracks: 856
# users: 863 playlists: 862 tracks: 857
# users: 864 playlists: 863 tracks: 858
# users: 865 playlists: 864 tracks: 859
# users: 866 playlists: 865 tracks: 860
# users: 867 playlists: 866 tracks: 861
# users: 868 playlists: 867 tracks: 862
# users: 869 playlists: 868 tracks: 863
# users: 870 playlists: 869 tracks: 864
# users: 871 playlists: 870 tracks: 865
# users: 872 playlists: 871 tracks: 866
# users: 873 playlists: 872 tracks: 867
# users: 874 playlists: 873 tracks: 868
# users: 875 playlists: 874 tracks: 869
# users: 876 playlists: 875 tracks: 870
# users: 877 playlists: 876 tracks: 871
# users: 878 playlists: 877 tracks: 872
# users: 879 playlists: 878 tracks: 873
# users: 880 playlists: 879 tracks: 874
# users: 957 playlists: 956 tracks: 946
# users: 958 playlists: 957 tracks: 947
# users: 959 playlists: 958 tracks: 948
# users: 960 playlists: 959 tracks: 949
# users: 961 playlists: 960 tracks: 950
# users: 962 playlists: 961 tracks: 951
# users: 963 playlists: 962 tracks: 952
# users: 964 playlists: 963 tracks: 953
# users: 965 playlists: 964 tracks: 954
# users: 966 playlists: 965 tracks: 955
# users: 967 playlists: 966 tracks: 956
# users: 968 playlists: 967 tracks: 957
# users: 969 playlists: 968 tracks: 958
# users: 970 playlists: 969 tracks: 959
# users: 971 playlists: 970 tracks: 960
# users: 972 playlists: 971 tracks: 961
# users: 973 playlists: 972 tracks: 962
# users: 974 playlists: 973 tracks: 963
# users: 975 playlists: 974 tracks: 964
# users: 976 playlists: 975 tracks: 965
# users: 977 playlists: 976 tracks: 966
# users: 978 playlists: 977 tracks: 967
# users: 979 playlists: 978 tracks: 968
# users: 980 playlists: 979 tracks: 969
# users: 981 playlists: 980 tracks: 970
# users: 982 playlists: 981 tracks: 971
# users: 983 playlists: 982 tracks: 972
# users: 984 playlists: 983 tracks: 973
# users: 985 playlists: 984 tracks: 974
# users: 986 playlists: 985 tracks: 975
# users: 987 playlists: 986 tracks: 976
# users: 988 playlists: 987 tracks: 977
# users: 989 playlists: 988 tracks: 978
# users: 990 playlists: 989 tracks: 979
# users: 991 playlists: 990 tracks: 980
# users: 992 playlists: 991 tracks: 981
# users: 993 playlists: 992 tracks: 982
# users: 994 playlists: 993 tracks: 983
# users: 995 playlists: 994 tracks: 984
# users: 996 playlists: 995 tracks: 985
# users: 997 playlists: 996 tracks: 986
# users: 998 playlists: 997 tracks: 987
# users: 999 playlists: 998 tracks: 988
# users: 1000 playlists: 999 tracks: 989
# users: 1001 playlists: 1000 tracks: 990
# users: 1002 playlists: 1001 tracks: 991
# users: 1003 playlists: 1002 tracks: 992
# users: 1004 playlists: 1003 tracks: 993
# users: 1005 playlists: 1004 tracks: 994
# users: 1006 playlists: 1005 tracks: 995
# users: 1007 playlists: 1006 tracks: 996
# users: 1008 playlists: 1007 tracks: 997
# users: 1009 playlists: 1008 tracks: 998
# users: 1010 playlists: 1009 tracks: 999
# users: 1011 playlists: 1010 tracks: 1000
# users: 1012 playlists: 1011 tracks: 1001

# %%
#Xuất dữ liệu được đọc từ file 
u=pd.read_csv('./Crawl_data/users.csv',index_col=[0])
p=pd.read_csv('./Crawl_data/playlists.csv',index_col=[0])
t=pd.read_csv('./Crawl_data/tracks.csv',index_col=[0])
display(u.head(),p.head(),t.head())
# Out:
#                    username first_name    last_name          full_name  \
# id
# 81750389              G_Vaz   gustavo          Vaz        gustavo  Vaz
# 83249072         Mr. Popper        NaN          NaN                NaN
# 92963897   ahmed abdel aziz     ahmed     abdelaziz   ahmed  abdelaziz
# 138901086       LEESTER1018        NaN          NaN                NaN
# 7792201          LAKPUEDE77      ZAIDA  TA' PACHECO  ZAIDA TA' PACHECO
#
#           description                                         avatar_url  \
# id
# 81750389          NaN  https://i1.sndcdn.com/avatars-000244437617-37i...
# 58773046   '83090027,23757868,49390532,15403530,81914622,...
# 81939204                                 '78161243,78161243'
# 63241849                                         '142612946'
#
#                                                  first_track  \
# id
# 259183402  https://soundcloud.com/muzicarec/vinne-free-fa...
# 81855177   https://soundcloud.com/freestyleent/trokero-lo...
# 58773046    https://soundcloud.com/sama-ramadan/vbuxbjytnob3
# 81939204                   https://soundcloud.com/zedd/union
# 63241849   https://soundcloud.com/dj-aneudy/salsa-dominic...
#
#                                            permalink_url
# id
# 259183402  https://soundcloud.com/1002/sets/free-falling
# 81855177       https://soundcloud.com/1014/sets/corridos
# 58773046           https://soundcloud.com/1015/sets/zizo
# 81939204            https://soundcloud.com/1018/sets/pop
# 63241849          https://soundcloud.com/1019/sets/salsa
#                                                   title  \
# id
# 278534059           VINNE - Free Falling (Original Mix)
# 10143348               Trokero Locochon - Gerardo Ortiz
# 83090027                      كل ده كان ليه - محمد محسن
# 78161243    Zedd - Clarity feat. Foxes (Zedd Union Mix)
# 142612946  Salsa Dominicana Mix 40 Minutos - Abril 2014
#
#                                                  description  track_format  \
# id
# 278534059  Don’t be afraid to free falling, go ahead and ...  single-track
# 10143348                                                 NaN  single-track
# 83090027                                                 NaN  single-track
# 78161243   - COMING OUT FEBRUARY 12 ON ITUNES -\r\nDownlo...  single-track
# 142612946  Aqui les dejo una mezcla de salsa dominicana l...  single-track
#
#            duration      genre      label_name  \
# id
# 278534059    364990   Nu Disco  Muzica Records
# 10143348     139390        NaN             NaN
# 83090027     339910  محمد محسن             NaN
# 78161243     208476      Music      interscope
# 142612946   2351057      Salsa             NaN
#
#                                                  tag_list        author  \
# id
# 278534059                                             NaN     muzicarec
# 10143348                                              NaN  freestyleent
# 83090027                                              NaN  sama-ramadan
# 78161243   Zedd Clarity Foxes Union Mix Interscope iTunes          zedd
# 142612946                                             NaN     dj-aneudy
#
#                      created_at          release_date         last_modified  \
# id
# 278534059  2016-08-16T18:20:59Z                   NaN  2018-02-11T01:15:40Z
# 10143348   2011-02-06T04:16:32Z                   NaN  2021-01-02T16:44:13Z
# 83090027   2013-03-13T17:29:20Z                   NaN  2021-05-17T18:21:12Z
# 78161243   2013-02-07T00:00:48Z  2013-02-12T00:00:00Z  2021-11-03T07:25:53Z
# 142612946  2014-04-02T00:38:11Z                   NaN  2020-12-19T06:02:34Z
#
#            comment_count  download_count  likes_count  playback_count  \
# id
# 278534059           10.0             0.0       1601.0         80684.0
# 10143348           128.0           651.0      19106.0       3522836.0
# 83090027           571.0           100.0      92244.0       3270446.0
# 78161243          6608.0             0.0     205527.0      12581419.0
# 142612946           88.0         55734.0      12286.0       1418242.0
#
#            reposts_count                                      permalink_url
# id
# 278534059            178  https://soundcloud.com/muzicarec/vinne-free-fa...
# 10143348            1388  https://soundcloud.com/freestyleent/trokero-lo...
# 83090027            9394   https://soundcloud.com/sama-ramadan/vbuxbjytnob3
# 78161243           38777                  https://soundcloud.com/zedd/union
# 142612946            727  https://soundcloud.com/dj-aneudy/salsa-dominic...
